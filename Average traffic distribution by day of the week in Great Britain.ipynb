# %% [markdown]
# # Average traffic distribution by day of the week in Great Britain

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import datetime
from dateutil.relativedelta import relativedelta
from datetime import date
from datetime import datetime
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_excel("C:/Users/44742/Documents/Daily road traffic data.xls")
df.head()
# Out:
#    Time of day  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# 0  00:00-01:00    11.2     10.8       11.4      12.1    13.2      18.7    20.5
# 1  01:00-02:00     7.0      7.1        7.4       7.8     8.6      11.8    12.7
# 2  02:00-03:00     5.8      6.2        6.4       6.7     7.2       8.8     8.7
# 3  03:00-04:00     7.1      7.2        7.3       7.6     7.9       8.0     7.0
# 4  04:00-05:00    13.9     13.2       13.1      13.2    13.1       9.8     7.4

# %%
df2= pd.read_excel("C:/Users/44742/Documents/export_dataframe.xlsx")

# %%
df.describe()
# Out:
#            Monday     Tuesday   Wednesday    Thursday      Friday    Saturday  \
# count   24.000000   24.000000   24.000000   24.000000   24.000000   24.000000
# mean   102.350000  104.133333  106.041667  108.104167  111.750000   89.570833
# std     72.222181   73.333839   74.255223   74.890352   77.243888   65.799263
# min      5.800000    6.200000    6.400000    6.700000    7.200000    8.000000
# 25%     28.700000   31.650000   33.400000   34.475000   34.400000   28.025000
# 50%    118.800000  123.400000  126.500000  131.150000  135.350000   80.700000
# 75%    162.300000  160.325000  163.400000  166.150000  177.850000  155.325000
# max    201.700000  208.300000  211.100000  213.100000  215.000000  186.600000
#
#            Sunday
# count   24.000000
# mean    77.816667
# std     61.278251
# min      7.000000
# 25%     20.300000
# 50%     61.250000
# 75%    138.175000
# max    171.000000

# %%
df.mean().plot(kind='bar', color='Red')
plt.ylabel('Average traffic flow')
# Out:
# C:\Users\44742\AppData\Local\Temp\ipykernel_26560\2973637876.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean().plot(kind='bar', color='Red')
# Text(0, 0.5, 'Average traffic flow')

# %%
df.mean().plot()
# Out:
# C:\Users\44742\AppData\Local\Temp\ipykernel_26560\2340813065.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean().plot()
# <AxesSubplot:>

# %%
df.corrwith(df2, axis = 0)
# Out:
# Actual Severity Rating       NaN
# Age Range                    NaN
# Experience in Current Role   NaN
# Friday                       NaN
# Monday                       NaN
# Potential Severity Rating    NaN
# PublishedRecordId            NaN
# Saturday                     NaN
# Sunday                       NaN
# Thursday                     NaN
# Tuesday                      NaN
# Wednesday                    NaN
# Year                         NaN
# month                        NaN
# time                         NaN
# dtype: float64

# %%
df2.head()
# Out:
#    PublishedRecordId                                       Region  \
# 0             131601                    East - Outstations & ROCs
# 1             131600                    East - Outstations & ROCs
# 2             131599  Yorkshire & North East - Outstations & ROCs
# 3             131598              North West - Outstations & ROCs
# 4             131597                            East - Operations
#
#                                    Site/Project  \
# 0                        South Mimms Outstation
# 1                        South Mimms Outstation
# 2                               Calder Park ROC
# 3                            Milness Outstation
# 4  DBFO - M40 J1-15 Denham to Warwick (area 30)
#
#                            Event Type Date and Time of Event  \
# 0  Undesired Circumstance / Near Miss    2022-08-09 18:20:00
# 1  Undesired Circumstance / Near Miss    2022-08-09 17:00:00
# 2  Undesired Circumstance / Near Miss    2022-08-08 20:14:00
# ...
